# %% [markdown]
# # Data Cleaning and Preparation
# - Included the VAK questions

# %%
import pandas as pd

# %% [markdown]
# ## Load data

# %%
# Load the CSV file containing responses
df = pd.read_csv('Dataset/responses_withVAKdom.csv')

# %%
df.head()
# Out:
#             Timestamp          Email Address  \
# 0  1/13/2021 14:25:10         test@gmail.com
# 1  1/13/2021 14:37:42  liyanashuib@gmail.com
# 2  1/17/2021 19:04:48   azirasuhot@gmail.com
# 3  1/17/2021 19:09:13    haslina_m@um.edu.my
# 4  1/18/2021 12:08:22   noorain277@um.edu.my
#
#   I understand that my participation is voluntary and that I am free to withdraw at any time without giving any reason. I, hereby agree to take part in the above study.  \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                              Agree
# 4                                              Agree
#
#    Gender Level of Study                  Field of study       Institutions  \
# 0  Female  Undergraduate                      Veterinary               test
# 1  Female   Postgraduate                       Computing                 UM
# ...

# %% [markdown]
# ### Remove unused column

# %%
columns_to_remove = ["Timestamp", "Email Address", "Country",
                    "I understand that my participation is voluntary and that I am free to withdraw at any time without giving any reason. I, hereby agree to take part in the above study.",
                    "Difficulties in Online Learning",
                     "Field of study",
                     "Institutions",
#                      "Preferred Communication Platform",
                     "Preferred Social Media Platform ",
                     "Are you familiar with the term learning style before this survey?",
                     "Are you aware what your learning style is?",
                     "Do you think knowing your own learning style is important in improving your learning ability?",
                     "6. Online Instructional Strategies/Assessment [Live Lecture]",
                     "6. Online Instructional Strategies/Assessment [Pre-Recorded Lecture]",
                     "6. Online Instructional Strategies/Assessment [Pre-Recorded Slide Lecture]",
                     "6. Online Instructional Strategies/Assessment [Demonstration]",
                     "6. Online Instructional Strategies/Assessment [Simulation]",
                     "6. Online Instructional Strategies/Assessment [Guided Learning (Hands on)]",
                     "6. Online Instructional Strategies/Assessment [Written assignment]",
                     "6. Online Instructional Strategies/Assessment [Digital Lab Experiments]",
                     "6. Online Instructional Strategies/Assessment [Live Group Discussions]",
                     "6. Online Instructional Strategies/Assessment [Forum]",
                     "6. Online Instructional Strategies/Assessment [Case Study]",
                     "6. Online Instructional Strategies/Assessment [Games]",
                     "6. Online Instructional Strategies/Assessment [Journaling]",
                     "6. Online Instructional Strategies/Assessment [YouTube Video]",
                     "6. Online Instructional Strategies/Assessment [Video based feedback]",
                     "6. Online Instructional Strategies/Assessment [Live Chat]",
                     "6. Online Instructional Strategies/Assessment [Brainstorming]",
                     "6. Online Instructional Strategies/Assessment [Online Debate]",
                     "6. Online Instructional Strategies/Assessment [Blog Writing]",
                     "6. Online Instructional Strategies/Assessment [Problem Based Learning]",
                     "6. Online Instructional Strategies/Assessment [Internet Research]",
                     "6. Online Instructional Strategies/Assessment [Invited Guest Online Lecture]",
                     "6. Online Instructional Strategies/Assessment [Virtual Field Trip]",
                     "6. Online Instructional Strategies/Assessment [Exit tickets (End Class Feedback)]",
                     "6. Online Instructional Strategies/Assessment [Learning Reflection]",
                     "6. Online Instructional Strategies/Assessment [Online Exercise/Practice]",
                     "6. Online Instructional Strategies/Assessment [Procedural Demonstration (Perform a given action)]",
                     "6. Online Instructional Strategies/Assessment [Concept Mapping]",
                     "6. Online Instructional Strategies/Assessment [Document Analysis]",
                     "6. Online Instructional Strategies/Assessment [Debugging]",
                     "6. Online Instructional Strategies/Assessment [Review (Article, Play, Movie, Audio, Book, etc.)]",
                     "6. Online Instructional Strategies/Assessment [Real Time Online Exam]",
                     "6. Online Instructional Strategies/Assessment [Individual Project/Assignment]",
                     "6. Online Instructional Strategies/Assessment [Group Project/Assignment]",
                     "6. Online Instructional Strategies/Assessment [Online Quiz/Test - MCQ]",
                     "6. Online Instructional Strategies/Assessment [Online Quiz/Test - Essay]",
                     "6. Online Instructional Strategies/Assessment [Online Quiz/Test - Open Book]",
                     "6. Online Instructional Strategies/Assessment [Peer Review Assessment Live Presentation]",
                     "6. Online Instructional Strategies/Assessment [Recorded Presentation]",
                     "6. Online Instructional Strategies/Assessment [Portfolio]",
                     "For technical or hands-on subject, which Online Instructional Strategies/Assessment do you prefer(list can be referred in previous question  eg. YouTube Video, Debugging or Live Lecture)?",
                     "Please share any comments or suggestions related to this issue. Thank You",
                     "Institutions.1",
                     "Faculty",
                     "Department"
                    ]
df.drop(columns=columns_to_remove, inplace=True, axis=1)
df.head()
# Out:
#    Gender Level of Study    Household Income  \
# 0  Female  Undergraduate    RM 3001 - 10 000
# 1  Female   Postgraduate    RM 3001 - 10 000
# 2  Female   Postgraduate    RM 3001 - 10 000
# 3  Female   Postgraduate  RM 10 001 - 25 000
# 4  Female   Postgraduate  RM 10 001 - 25 000
#
#                              Preferred learning mode  \
# 0                                       Face to Face
# 1  Face to Face, Synchronous Online Learning (Rea...
# 2                                       Face to Face
# 3  Face to Face, Asynchronous Online Learning (On...
# 4                                       Face to Face
#
#                     Preferred Communication Platform  \
# 0                                           Whatsapp
# 1                                           Whatsapp
# 2  Email, University eLearning Chat Room, Whatsap...
# 3                                    Email, Whatsapp
# 4                                           Whatsapp
#
# ...

# %% [markdown]
# ### Remove test data
# - The first row of the dataset is a dummy data

# %%
# Drop the first row (index 0)
df = df.drop(0).reset_index(drop=True)
df.head()
# Out:
#    Gender Level of Study    Household Income  \
# 0  Female   Postgraduate    RM 3001 - 10 000
# 1  Female   Postgraduate    RM 3001 - 10 000
# 2  Female   Postgraduate  RM 10 001 - 25 000
# 3  Female   Postgraduate  RM 10 001 - 25 000
# 4  Female  Undergraduate    RM 3001 - 10 000
#
#                              Preferred learning mode  \
# 0  Face to Face, Synchronous Online Learning (Rea...
# 1                                       Face to Face
# 2  Face to Face, Asynchronous Online Learning (On...
# 3                                       Face to Face
# 4                                       Face to Face
#
#                     Preferred Communication Platform  \
# 0                                           Whatsapp
# 1  Email, University eLearning Chat Room, Whatsap...
# 2                                    Email, Whatsapp
# 3                                           Whatsapp
# 4    Email, University eLearning Chat Room, Whatsapp
#
# ...

# %% [markdown]
# ## Standardise Data
#
# For columns:
# - Level of Study

# %%
distinct_values = df['Level of Study'].unique()

# Print all distinct values
print("Distinct values in 'Level of Study':")
for value in distinct_values:
    print(value)
# Out:
# Distinct values in 'Level of Study':
# Postgraduate
# Undergraduate
# Master
# PhD
# Certificate/Diploma

# %%
# Mapping different representations to a standardized value
standardized_values = {
    'PhD': 'Postgraduate',
    'Master': 'Postgraduate'
}

# Replace values in the 'Institutions' column with the standardized values
df['Level of Study'] = df['Level of Study'].replace(standardized_values)

# %%
distinct_values = df['Household Income'].unique()

# Print all distinct values
for value in distinct_values:
    print(value)
# Out:
# RM 3001 - 10 000
# RM 10 001 - 25 000
# Less than RM 3000
# RM 4,850 – RM10,959
# Less than RM 4,849
# More than RM10,960

# %%
# Mapping different representations to a standardized value
standardized_values = {
    "Less than RM 3000": 'Less than RM 4,849',
    "RM 3001 - 10 000": 'RM 4,850 – RM10,959',
    "RM 10 001 - 25 000": 'More than RM10,960'
}

# Replace values in the 'Institutions' column with the standardized values
df['Household Income'] = df['Household Income'].replace(standardized_values)

# %% [markdown]
# ## EDA: Tableau
# - Save the cleaned & standardised data to a new CSV

# %%
# df.to_csv('Dataset/cleaned_response_new.csv', index=False) ## for EDA in Tableau

# %%
# distinct_values = df['Institutions'].unique()

# # Print all distinct values
# print("Distinct values in 'Institutions':")
# for value in distinct_values:
#     print(value)

# %%
# # Mapping different representations to a standardized value
# standardized_values = {
#     'University of Malaya': 'UM',
#     'University of Malaya ': 'UM',
#     'University of malaya': 'UM',
#     'university of malaya': 'UM',
#     'Uni malaya': 'UM',
#     'Universiti Malaya': 'UM',
#     'University Malaya': 'UM',
#     'University malaya': 'UM',
#     'Univeriti Malaya': 'UM',
#     'Um': 'UM'
# }

# # Replace values in the 'Institutions' column with the standardized values
# df['Institutions'] = df['Institutions'].replace(standardized_values)

# %%
# distinct_values = df['Country'].unique()

# # Print all distinct values
# print("Distinct values in 'Country':")
# for value in distinct_values:
#     print(value)

# %%
# # Mapping different representations to a standardized value
# standardized_values = {
#     'Malaysia ': 'Malaysia',
#     'Kuala lumpur': 'Malaysia',
#     'malaysia': 'Malaysia',
#     'MALAYSIA ': 'Malaysia',
#     'Shah Alam': 'Malaysia',
#     'Terengganu': 'Malaysia',
#     'Selangor': 'Malaysia',
#     'Malaydia': 'Malaysia',
#     'Perlis': 'Malaysia',
#     'Kelantan': 'Malaysia',
#     'Perak': 'Malaysia',
#     'Kuala Lumpur': 'Malaysia',
#     'Pahang': 'Malaysia',
#     'Sabah ' : 'Malaysia',
#     'Kedah': 'Malaysia',
#     'Johor ': 'Malaysia',
#     'M\'sia': 'Malaysia',
#     'Malacca': 'Malaysia',
#     'malaysia ' : 'Malaysia',
#     'INDIA': 'India',
#     'wp kuala lumpur': 'Malaysia',
#     'TERENGGANU': 'Malaysia',
#     'Malaysia, Selangor': 'Malaysia',
#     'JOHOR': 'Malaysia',
#     'MALAYSIA': 'Malaysia',
#     'Kedah-Malaysia': 'Malaysia',
#     'KL': 'Malaysia',
#     'kuala lumpur': 'Malaysia',
#     'kuala Lumpur': 'Malaysia',
#     'KELANTAN': 'Malaysia',
#     'Rawang': 'Malaysia',
#     'Jerantut,Pahang': 'Malaysia',
#     'johor': 'Malaysia',
#     'PERAK': 'Malaysia',
#     'Miri, Sarawak, Malaysia': 'Malaysia',
#     'TANJONG MALIM PERAK': 'Malaysia',
#     'Sabah': 'Malaysia',
#     'KEDAH': 'Malaysia',
#     'selangor': 'Malaysia',
#     'Kunak, Sabah': 'Malaysia',
#     'Johor ': 'Malaysia',
#     'Johor': 'Malaysia',
#     'kuala kubu bharu , selangor': 'Malaysia',
#     'Malayy': 'Malaysia',
#     'Bangladesh ': 'Bangladesh',
#     'china': 'China',
#     'China ': 'China',
#     'Melaka': 'Malaysia',
#     'PASIR MAS' : 'Malaysia',
#     'PASIR MAS ': 'Malaysia',
#     'Penang': 'Malaysia',
#     'Kelantan ' : 'Malaysia',
#     'Johor bahru': 'Malaysia',
#     'Pasir Mas': 'Malaysia',
#     'kelantan': 'Malaysia',
#     'pasir mas': 'Malaysia',
#     'Kedah ' : 'Malaysia',
#     'Pulau pinang': 'Malaysia',
#     'Pasir Mas Kelantan': 'Malaysia',
#     ' Malaysia': 'Malaysia',
#     'KELANTAN ' : 'Malaysia',
#     'KUALA TERENGGANU': 'Malaysia',
#     'Kuala Terengganu ' : 'Malaysia',
#     'terengganu': 'Malaysia',
#     'PAHANG': 'Malaysia',
#     'Terrengganu': 'Malaysia',
#     'MY': 'Malaysia'
# }

# # Replace values in the 'Institutions' column with the standardized values
# df['Country'] = df['Country'].replace(standardized_values)

# %% [markdown]
# ## Data Granularity
#
# #### Transforms  multi-option cells into rows with single options
# For columns with multiple options, we will split the options into separate rows for each value using the explode() function.
# For example, if a row initially contained two learning modes 'Face to Face' and 'Synchronous Online Learning (Real Time)', after exploding, it will generate two rows; one for each learning mode.
#
# The column involved: Preferred learning mode
# Options:
# - Asynchronous Online Learning (On your own time)
# - Face to Face
# - Synchronous Online Learning (Real Time)

# %%
# from sklearn.preprocessing import MultiLabelBinarizer

# %%
# # Splitting multiple options and creating lists of options
# df['Preferred learning mode'] = df['Preferred learning mode'].str.split(', ')
# df['Preferred Social Media Platform '] = df['Preferred Social Media Platform '].str.split(', ')
# df['Preferred Communication Platform'] = df['Preferred Communication Platform'].str.split(', ')


# # Initializing the MultiLabelBinarizer
# mlb = MultiLabelBinarizer()


# # Encoding the options into binary columns
# encoded_data = pd.DataFrame(mlb.fit_transform(df['Preferred learning mode']), columns=mlb.classes_, index=df.index)
# # Concatenating the original DataFrame with the encoded data
# df_encoded = pd.concat([df, encoded_data], axis=1)

# encoded_data = pd.DataFrame(mlb.fit_transform(df['Preferred Social Media Platform ']), columns=mlb.classes_, index=df.index)
# df_encoded = pd.concat([df_encoded, encoded_data], axis=1)

# encoded_data = pd.DataFrame(mlb.fit_transform(df['Preferred Communication Platform']), columns=mlb.classes_, index=df.index)
# df_encoded = pd.concat([df_encoded, encoded_data], axis=1)


# columns_to_remove = ["Preferred learning mode", 'Preferred Social Media Platform ', 'Preferred Communication Platform']

# df = df_encoded.drop(columns=columns_to_remove, axis=1)
# df.head()

# %%
# Splitting column by ', ' with multiple options
df['Preferred learning mode'] = df['Preferred learning mode'].str.split(', ')
df['Preferred Communication Platform'] = df['Preferred Communication Platform'].str.split(', ')
# df['Preferred Social Media Platform '] = df['Preferred Social Media Platform '].str.split(', ')

# Exploding the columns to separate rows for each value
df = df.explode('Preferred learning mode').reset_index(drop=True)
df = df.explode('Preferred Communication Platform').reset_index(drop=True)
# df = df.explode('Preferred Social Media Platform ').reset_index(drop=True)

df.head()
# Out:
#    Gender Level of Study     Household Income  \
# 0  Female   Postgraduate  RM 4,850 – RM10,959
# 1  Female   Postgraduate  RM 4,850 – RM10,959
# 2  Female   Postgraduate  RM 4,850 – RM10,959
# 3  Female   Postgraduate  RM 4,850 – RM10,959
# 4  Female   Postgraduate  RM 4,850 – RM10,959
#
#                    Preferred learning mode Preferred Communication Platform  \
# 0                             Face to Face                         Whatsapp
# 1  Synchronous Online Learning (Real Time)                         Whatsapp
# 2                             Face to Face                            Email
# 3                             Face to Face   University eLearning Chat Room
# 4                             Face to Face                         Whatsapp
#
#   Learning Objects [Slide presentation] Learning Objects [Book]  \
# 0                            Somewhat\t              Somewhat\t
# 1                            Somewhat\t              Somewhat\t
# ...

# %%
distinct_values = df['Preferred learning mode'].unique()

# Print all distinct values
# print("Distinct values in 'Preferred learning mode':")
for value in distinct_values:
    print(value)
# Out:
# Face to Face
# Synchronous Online Learning (Real Time)
# Asynchronous Online Learning (On your own time)

# %%
distinct_values = df['Preferred Communication Platform'].unique()
# distinct_values = df['Preferred Social Media Platform '].unique()

# Print all distinct values
# print("Distinct values in 'Preferred learning mode':")
for value in distinct_values:
    print(value)
# Out:
# Whatsapp
# Email
# University eLearning Chat Room
# Call
# Telegram
# discord
# Zoom
# Google meet
# Microsoft Teams
# Microsoft team
# MICROSOFT TEAMS
# ZOOM
# Microsoft team
# Google Meet
# Lecture Hall
# Teams
# Teams or Google Meet
# Cisco Webex
# Google Classroom
# MS Team
# Google Classroom
# Kaizala
# telegram
# Discord
# Google meet
# Google Meet

# %%
# Mapping different representations to a standardized value
standardized_values = {
#     Whatsapp
#     Email
#     University eLearning Chat Room
#     Call
#     Telegram
    'discord': 'Discord',
#     Zoom
    'Google meet': 'Google Meet',
#     Microsoft Teams
    'Microsoft team':  'Microsoft Teams',
    'MICROSOFT TEAMS': 'Microsoft Teams',
    'ZOOM': 'Zoom',
    'Microsoft team ': 'Microsoft Teams',
#     Google Meet
#     Lecture Hall
    'Teams': 'Microsoft Teams',
    'Teams or Google Meet': 'Microsoft Teams',
#     Cisco Webex
#     Google Classroom
    'MS Team': 'Microsoft Teams',
    'Google Classroom ':  'Google Classroom',
#     Kaizala
    'telegram': 'Telegram',
#     Discord
    'Google meet ': 'Google Meet', 
    'Google Meet ': 'Google Meet'
}

# Replace values in the 'Institutions' column with the standardized values
df['Preferred Communication Platform'] = df['Preferred Communication Platform'].replace(standardized_values)
df.head()
# Out:
#    Gender Level of Study     Household Income  \
# 0  Female   Postgraduate  RM 4,850 – RM10,959
# 1  Female   Postgraduate  RM 4,850 – RM10,959
# 2  Female   Postgraduate  RM 4,850 – RM10,959
# 3  Female   Postgraduate  RM 4,850 – RM10,959
# 4  Female   Postgraduate  RM 4,850 – RM10,959
#
#                    Preferred learning mode Preferred Communication Platform  \
# 0                             Face to Face                         Whatsapp
# 1  Synchronous Online Learning (Real Time)                         Whatsapp
# 2                             Face to Face                            Email
# 3                             Face to Face   University eLearning Chat Room
# 4                             Face to Face                         Whatsapp
#
#   Learning Objects [Slide presentation] Learning Objects [Book]  \
# 0                            Somewhat\t              Somewhat\t
# 1                            Somewhat\t              Somewhat\t
# ...

# %%
# Mapping different representations to a standardized value
standardized_values = {
#     Whatsapp
#     Email
#     University eLearning Chat Room
#     Call
#     Telegram
    'Discord': 'Others',
    'Zoom': 'Others',
    'Google Meet': 'Others',
    'Microsoft Teams': 'Others',
    'Lecture Hall': 'Others',
    'Cisco Webex': 'Others',
    'Google Classroom': 'Others',
    'Kaizala': 'Others'
}

# Replace values in the 'Institutions' column with the standardized values
df['Preferred Communication Platform'] = df['Preferred Communication Platform'].replace(standardized_values)
df.head()
# Out:
#    Gender Level of Study     Household Income  \
# 0  Female   Postgraduate  RM 4,850 – RM10,959
# 1  Female   Postgraduate  RM 4,850 – RM10,959
# 2  Female   Postgraduate  RM 4,850 – RM10,959
# 3  Female   Postgraduate  RM 4,850 – RM10,959
# 4  Female   Postgraduate  RM 4,850 – RM10,959
#
#                    Preferred learning mode Preferred Communication Platform  \
# 0                             Face to Face                         Whatsapp
# 1  Synchronous Online Learning (Real Time)                         Whatsapp
# 2                             Face to Face                            Email
# 3                             Face to Face   University eLearning Chat Room
# 4                             Face to Face                         Whatsapp
#
#   Learning Objects [Slide presentation] Learning Objects [Book]  \
# 0                            Somewhat\t              Somewhat\t
# 1                            Somewhat\t              Somewhat\t
# ...

# %%
# # check duplication
# duplicated_rows = df[df.duplicated(subset=['Email Address'], keep=False)]

# if duplicated_rows.empty:
#     print("The column does not contain duplicate values.")
# else:
#     print("The following rows contain duplicate values in the 'Email Address' column:")
#     print(duplicated_rows['Email Address'])

# %% [markdown]
# ### Check for null values

# %%
# Checking for null values in the dataframe
null_counts = df.isnull().sum()

# Displaying columns with null values
columns_with_null = null_counts[null_counts > 0]
if columns_with_null.empty:
    print("No null values found in the DataFrame.")
else:
    print("Columns with null values:")
    print(columns_with_null)
# Out:
# No null values found in the DataFrame.

# %% [markdown]
# ## Correlation

# %% [markdown]
# ## Encode data

# %% [markdown]
# The columns to be encoded:
#    - Gender
#    - Level of study
#    - Household income
#    - Prefered learning mode
#    - Learning objects preference
#    - VAK questions
#    - Dominant VAK

# %%
# !pip install scikit-learn
# !pip install category_encoders

# %% [markdown]
# ### Ordinal encoding
#
# #### Using self-defined mappings

# %% [markdown]
# #### 1. Demographics

# %%
# get the demographics columns
# column 1 till column 3
col1_col3_df = df.iloc[:, :3]
col1_col3_df.head()
# Out:
#    Gender Level of Study     Household Income
# 0  Female   Postgraduate  RM 4,850 – RM10,959
# 1  Female   Postgraduate  RM 4,850 – RM10,959
# 2  Female   Postgraduate  RM 4,850 – RM10,959
# 3  Female   Postgraduate  RM 4,850 – RM10,959
# 4  Female   Postgraduate  RM 4,850 – RM10,959

# %%
# Define your custom mapping
custom_mapping = {
    "Male": 1,
    "Female": 2,
    "Postgraduate": 1,
    "Undergraduate": 2,
    "Certificate/Diploma": 3,
#     "Malaysia": 1,
#     "India": 0,
#     "Egypt": 0,
#     "Indonesia": 0,
#     "China": 0,
#     "Bangladesh": 0,
#     "Somalia": 0,
#     "Sudan": 0,
#     "Yemen": 0,
#     "Pakistan": 0,
#     "Less than RM 3000": 1,    #equalvalent to 'less than RM4849'
    "Less than RM 4,849": 1,   #equalvalent to 'less than RM4849'
#     "RM 3001 - 10 000": 2,     #equalvalent to 'RM 4,850 – RM10,959'
    "RM 4,850 – RM10,959": 2,  #equalvalent to 'RM 4,850 – RM10,959'
#     "RM 10 001 - 25 000": 3,   #equalvalent to 'More than RM10,960'
    "More than RM10,960": 3,   #equalvalent to 'More than RM10,960'
}

# Perform ordinal encoding using the defined mapping
for column in col1_col3_df.columns:
    df[column] = df[column].map(custom_mapping)

# Display the encoded DataFrame
df.head()
# Out:
#    Gender  Level of Study  Household Income  \
# 0       2               1                 2
# 1       2               1                 2
# 2       2               1                 2
# 3       2               1                 2
# 4       2               1                 2
#
#                    Preferred learning mode Preferred Communication Platform  \
# 0                             Face to Face                         Whatsapp
# 1  Synchronous Online Learning (Real Time)                         Whatsapp
# 2                             Face to Face                            Email
# 3                             Face to Face   University eLearning Chat Room
# 4                             Face to Face                         Whatsapp
#
#   Learning Objects [Slide presentation] Learning Objects [Book]  \
# 0                            Somewhat\t              Somewhat\t
# 1                            Somewhat\t              Somewhat\t
# ...

# %% [markdown]
# #### 2. Learning objects

# %%
# Get the learning objects column
learning_df = df.iloc[:, 5:18]
learning_df.head()
# Out:
#   Learning Objects [Slide presentation] Learning Objects [Book]  \
# 0                            Somewhat\t              Somewhat\t
# 1                            Somewhat\t              Somewhat\t
# 2                             Very Much              Somewhat\t
# 3                             Very Much              Somewhat\t
# 4                             Very Much              Somewhat\t
#
#   Learning Objects [Lecture Note] Learning Objects [Educational game]  \
# 0                      Somewhat\t                          Somewhat\t
# 1                      Somewhat\t                          Somewhat\t
# 2                       Very Much                          Somewhat\t
# 3                       Very Much                          Somewhat\t
# 4                       Very Much                          Somewhat\t
#
#   Learning Objects [Video] Learning Objects [Audio-recorded lecture]  \
# 0               Somewhat\t                                Somewhat\t
# ...

# %%
custom_mapping = {
    "Not at All": 0,
    "Not Really": 0,
    "Undecided": 0,
    "Somewhat\t": 0,
    "Very Much": 1
}

# Perform ordinal encoding using the defined mapping
for column in learning_df.columns:
    df[column] = df[column].map(custom_mapping)

# Display the encoded DataFrame
df.head()
# Out:
#    Gender  Level of Study  Household Income  \
# 0       2               1                 2
# 1       2               1                 2
# 2       2               1                 2
# 3       2               1                 2
# 4       2               1                 2
#
#                    Preferred learning mode Preferred Communication Platform  \
# 0                             Face to Face                         Whatsapp
# 1  Synchronous Online Learning (Real Time)                         Whatsapp
# 2                             Face to Face                            Email
# 3                             Face to Face   University eLearning Chat Room
# 4                             Face to Face                         Whatsapp
#
#    Learning Objects [Slide presentation]  Learning Objects [Book]  \
# 0                                      0                        0
# 1                                      0                        0
# ...

# %% [markdown]
# #### 3. Dominant VAK

# %%
# Get the dominant VAK column for encoding
# column 48
domvak_df = df.iloc[:, 48:]
domvak_df.head()
# Out:
#   Dominant_VAK
# 0       Visual
# 1       Visual
# 2       Visual
# 3       Visual
# 4       Visual

# %%
# Define your custom mapping
custom_mapping = {
    "Visual": 1,
    "Auditory": 2,
    "Kinesthetic": 3
}

# Perform ordinal encoding using the defined mapping
for column in domvak_df.columns:
    df[column] = df[column].map(custom_mapping)

# Display the encoded DataFrame
df.head()
# Out:
#    Gender  Level of Study  Household Income  \
# 0       2               1                 2
# 1       2               1                 2
# 2       2               1                 2
# 3       2               1                 2
# 4       2               1                 2
#
#                    Preferred learning mode Preferred Communication Platform  \
# 0                             Face to Face                         Whatsapp
# 1  Synchronous Online Learning (Real Time)                         Whatsapp
# 2                             Face to Face                            Email
# 3                             Face to Face   University eLearning Chat Room
# 4                             Face to Face                         Whatsapp
#
#    Learning Objects [Slide presentation]  Learning Objects [Book]  \
# 0                                      0                        0
# 1                                      0                        0
# ...

# %% [markdown]
# ### One-hot Encoding
# Use one-hot encoding for the learning style questions columns which consist of 30 questions.

# %% [markdown]
# #### 1. VAK questions
# - Extract columns
# - Perform one-hot encoding

# %%
# get the vak questions columns
# column 18 to column 47
qcolumns_df = df.iloc[:, 18:48]
qcolumns_df.head()
# Out:
#   1. When operating new equipment for the first time I prefer to  \
# 0           Have a go and learn by "trial and error"
# 1           Have a go and learn by "trial and error"
# 2                              Read the instructions
# 3                              Read the instructions
# 4                              Read the instructions
#
#   2. When seeking travel directions I 3. When cooking a new dish I  \
# 0                       Look at a map              Follow a recipe
# 1                       Look at a map              Follow a recipe
# 2                       Look at a map              Follow a recipe
# 3                       Look at a map              Follow a recipe
# 4                       Look at a map              Follow a recipe
#
#       4. To teach someone something I    5. I tend to say  6. I tend to say   \
# 0                    Explain verbally  I know how you feel        Let me try
# ...

# %%
# Encode categorical variables (one-hot encoding)
df = pd.get_dummies(df, columns=qcolumns_df.columns, prefix=qcolumns_df.columns)
df.head()
# Out:
#    Gender  Level of Study  Household Income  \
# 0       2               1                 2
# 1       2               1                 2
# 2       2               1                 2
# 3       2               1                 2
# 4       2               1                 2
#
#                    Preferred learning mode Preferred Communication Platform  \
# 0                             Face to Face                         Whatsapp
# 1  Synchronous Online Learning (Real Time)                         Whatsapp
# 2                             Face to Face                            Email
# 3                             Face to Face   University eLearning Chat Room
# 4                             Face to Face                         Whatsapp
#
#    Learning Objects [Slide presentation]  Learning Objects [Book]  \
# 0                                      0                        0
# 1                                      0                        0
# ...

# %% [markdown]
# #### 2. Preferred learning mode

# %%
prefered_columns = ['Preferred learning mode', 'Preferred Communication Platform']
# prefered_columns = ['Preferred Communication Platform']

# Encode categorical variables (one-hot encoding)
df = pd.get_dummies(df, columns=prefered_columns, prefix=prefered_columns)
df.head()
# Out:
#    Gender  Level of Study  Household Income  \
# 0       2               1                 2
# 1       2               1                 2
# 2       2               1                 2
# 3       2               1                 2
# 4       2               1                 2
#
#    Learning Objects [Slide presentation]  Learning Objects [Book]  \
# 0                                      0                        0
# 1                                      0                        0
# 2                                      1                        0
# 3                                      1                        0
# 4                                      1                        0
#
#    Learning Objects [Lecture Note]  Learning Objects [Educational game]  \
# 0                                0                                    0
# 1                                0                                    0
# 2                                1                                    0
# ...

# %% [markdown]
# ### Export final dataframe to a CSV file

# %%
# final_df.to_csv('Dataset/encoded_response.csv', index=False)
# df.to_csv('Dataset/encoded_response_withQues.csv', index=False)

df.to_csv('Dataset/encoded_new_response_withQues.csv', index=False)
