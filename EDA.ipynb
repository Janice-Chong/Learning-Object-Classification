# %% [markdown]
# ## Learning Objects Preferrences Based on Dominant VAK
#
# Count all the 1s (Chose 'Very Much' option) for each learning objects based on dominant VAK

# %%
import pandas as pd

# %%
# Load the CSV file containing responses
df = pd.read_csv('Dataset/encoded_response_withQues.csv')
df.head()
# Out:
#    Gender  Level of Study  Household Income  \
# 0       2               1                 2
# 1       2               1                 2
# 2       2               1                 2
# 3       2               1                 3
# 4       2               1                 3
#
#    Learning Objects [Slide presentation]  Learning Objects [Book]  \
# 0                                      0                        0
# 1                                      0                        0
# 2                                      1                        0
# 3                                      1                        1
# 4                                      1                        1
#
#    Learning Objects [Lecture Note]  Learning Objects [Educational game]  \
# 0                                0                                    0
# 1                                0                                    0
# 2                                1                                    0
# ...

# %%
# Count occurrences of '1' for each learning object per Dominant VAK
learning_objects = df.iloc[:, 3:16]  # Exclude the Dominant_VAK column
learning_objects.head()
# Out:
#    Learning Objects [Slide presentation]  Learning Objects [Book]  \
# 0                                      0                        0
# 1                                      0                        0
# 2                                      1                        0
# 3                                      1                        1
# 4                                      1                        1
#
#    Learning Objects [Lecture Note]  Learning Objects [Educational game]  \
# 0                                0                                    0
# 1                                0                                    0
# 2                                1                                    0
# 3                                1                                    0
# 4                                1                                    0
#
#    Learning Objects [Video]  Learning Objects [Audio-recorded lecture]  \
# ...

# %%
counts = learning_objects.groupby(df['Dominant_VAK']).sum().reset_index()

counts
# Out:
#    Dominant_VAK  Learning Objects [Slide presentation]  \
# 0             1                                    414
# 1             2                                    205
# 2             3                                    159
#
#    Learning Objects [Book]  Learning Objects [Lecture Note]  \
# 0                      238                              568
# 1                      138                              280
# 2                       97                              214
#
#    Learning Objects [Educational game]  Learning Objects [Video]  \
# 0                                  283                       389
# 1                                  126                       208
# 2                                  138                       164
#
#    Learning Objects [Audio-recorded lecture]  \
# 0                                        290
# 1                                        161
# 2                                        106
#
#    Learning Objects [Animated instruction]  \
# ...

# %%
counts.to_csv('Dataset/eda.csv', index=False) ## for EDA in Tableau
