# %% [markdown]
# # To determine the dominant VAK from a user response

# %%
import pandas as pd

# !pip install pandas

# %% [markdown]
# ### Read Data

# %%
df = pd.read_csv('Dataset/LOSurvey.csv')

# %% [markdown]
# ### Data Preparation
# #### Extract columns for VAK Questionaires (30 Questions)

# %%
# Extract columns 71 to 100
vak_df = df.iloc[:, 70:100]

# Display the selected columns
# print(vak_df)
vak_df.head()
# Out:
#   1. When operating new equipment for the first time I prefer to  \
# 0                              Read the instructions
# 1           Have a go and learn by "trial and error"
# 2                              Read the instructions
# 3                              Read the instructions
# 4               Listen to or ask for an explaination
#
#   2. When seeking travel directions I 3. When cooking a new dish I  \
# 0                       Look at a map              Follow a recipe
# 1                       Look at a map              Follow a recipe
# 2                       Look at a map              Follow a recipe
# 3           Ask for spoken directions              Follow a recipe
# 4           Ask for spoken directions              Follow a recipe
#
#       4. To teach someone something I           5. I tend to say   \
# 0                  Write Instructions  I hear what you are saying
# 1                    Explain verbally         I know how you feel
# ...

# %% [markdown]
# #### Get survey questions

# %%
# Get the column names from the DataFrame and store them in a list
questions_lst = vak_df.columns.tolist()

# Print the list of column names
print(questions_lst)
# Out:
# ['1. When operating new equipment for the first time I prefer to', '2. When seeking travel directions I', '3. When cooking a new dish I', '4. To teach someone something I', '5. I tend to say ', '6. I tend to say ', '7. I tend to say ', '8. Complaining about faulty goods I tend to', '9. I prefer these leisure activities', '10. When shopping generally I tend to', '11. Choosing a holiday I', '12. Choosing a new car I', '13. Learning a new skill', '14. Choosing from a restaurant menu', '15. When listening to a band', '16. When concentrating I', '17. I remember things best by', '18. My first memory is of', '19. When anxious I', '20. I feel especially connected to others because of', '21. When I revise for an exam, I', '22. When explaining something to someone, I tend to', '23. My main interests are', '24. Most of my free time is spent', '25. When I first contact a new person', '26. I first notice how people', '27. If I am very angry', '28. I find it easiest to remember', '29. I think I ca
# ...

# %% [markdown]
# #### Get survey responses
# To form MCQ options

# %%
# Create a list to store lists of unique responses for each column
unique_responses_by_column = []

# Iterate through each column and extract unique responses
for column in vak_df.columns:
    unique_responses = vak_df[column].unique().tolist()
    unique_responses_by_column.append(unique_responses)

# Print the lists of unique responses grouped by column
for i, column in enumerate(vak_df.columns):
    print(f"Unique responses for column '{column}':")
    for j, response in enumerate(unique_responses_by_column[i]):
        print(f"{j + 1}. {response}")
    print()

# You can access unique responses for a specific column using unique_responses_by_column[column_index]
# For example, to access unique responses for the first column: unique_responses_by_column[0]
# Out:
# Unique responses for column '1. When operating new equipment for the first time I prefer to':
# 1. Read the instructions
# 2. Have a go and learn by "trial and error"
# 3. Listen to or ask for an explaination
#
# Unique responses for column '2. When seeking travel directions I':
# 1. Look at a map
# 2. Ask for spoken directions
# 3. Follow my nose or maybe use a compass
#
# Unique responses for column '3. When cooking a new dish I':
# 1. Follow a recipe
# 2. Follow my instinct, tasting as I cook
# 3. Call a friend for explaination
#
# Unique responses for column '4. To teach someone something I':
# 1. Write Instructions
# 2. Explain verbally
# 3. Demonstrate and let them have a go
#
# Unique responses for column '5. I tend to say ':
# 1. I hear what you are saying
# 2. I know how you feel
# 3. I see what you mean
#
# Unique responses for column '6. I tend to say ':
# 1. Show me
# 2. Let me try
# 3. Tell me
#
# Unique responses for column '7. I tend to say ':
# ...

# %% [markdown]
# ### Define the list of questions and MCQ options
# #### Manually

# %%
mcq_options = [
    ["Read the instructions", "Listen to or ask for an explaination", "Have a go and learn by trial and error"],
    ["Look at a map", "Ask for spoken directions", "Follow my nose or maybe use a compass"],
    ["Follow a recipe", "Call a friend for explaination", "Follow my instinct, tasting as I cook"],
    ["Write Instructions", "Explain verbally", "Demonstrate and let them have a go"],
    ["I see what you mean", "I hear what you are saying", "I know how you feel"],
    ["Show me", "Tell me", "Let me try"],
    ["Watch how I do it", "Listen to me explain", "You have a go"],
    ["Write a letter", "Phone", "Go back to the store, or send the faulty item to the head office"],
    ["Museums or galleries", "Music or conversation", "Physical activities or making things"],
    ["Look and decide", "Discuss with shop staff", "Try on, handle or test"],
    ["Read the brochures", "Listen to recommendations", "Imagine the experience"],
    ["Read the reviews", "Discuss with friends", "Test-drive what you fancy"],
    ["I watch what the teacher is doing", "I talk through with the teacher exactly what I am supposed to do", "I like to give it a try and work it out as I go along by doing it"],
    ["I imagine what the food will look like", "I talk through the options in my head", "I imagine what  the food will taste like"],
    ["I sing along to the lyrics (in my head or out loud)", "I listen to the lyrics and the beats", "I move in time with the music"],
    ["Focus on the words or pictures in front of me", "Discuss the problem and possible solutions in my head", "Move around a lot, fiddle with pens and pencils and touch unrelated things"],
    ["Writing notes or keeping printed details", "Saying them aloud or repeating words and key points in my head", "Doing and practicing the activity or imagining it being done"],
    ["Looking at something", "Being spoken to", "Doing something"], 
    ["Visualize the worst case scenarios", "Talk over in my head what worries me most", "Can't sit still, fiddle and move around constantly"],
    ["How they look", "What they say to me", "How they make me"],
    ["Write lots of revision notes", "I talk over my notes, to myself or to other people", "Imagine making the movement or creating the formula"],
    ["Show them what I mean", "Explain to them in different ways until they understand", "Encourage them to try and talk them through the idea as they try"],
    ["Photography or watching films or people watching", "Listening to music or listening to the radio or talking to friends", "Physical/sports activities or fine wines, fine foods or dancing"],
    ["Watching television", "Talking to friends", "Doing physical activity or making things"],
    ["I arrange a face to face meeting", "I talk to them on the telephone", "I try to get together to share an activity"],
    ["Look and dress", "Sound and speak", "Stand and move"],
    ["I keep replaying in my mind what it is that has upset me", "I shout lots and tell people how I feel", "I stomp about, slam doors and throw things"],
    ["Faces", "Names", "Things I have done"],
    ["They avoid looking at you", "Their voice changes", "The vibes I get from them"], 
    ["I say \"it's great to see you!\"", "I say \"it's great to hear your voice!\"", "I give them a hug or a handshake"]
]

# %%
# # Count rows with the same answers in the specified column
# answer_counts = df['1. When operating new equipment for the first time I prefer to'].value_counts()

# # Print all available answers and their counts
# for answer, count in answer_counts.items():
#     print(f"Answer: {answer}, Count: {count}")

# %% [markdown]
# ### Get User to Answer the VAK Questionnaire
# #### Print the VAK outcomes and determine the dominant learning style

# %%
visual_count = 0
auditory_count = 0
kinesthetic_count = 0

# Get user responses to the questions
for i, question in enumerate(questions_lst):
    print(f"{i + 1}. {question}")
#     for j, option in enumerate(unique_responses_by_column[i]):
#         print(f"{chr(65 + j)}) {option}")
    for j, option in enumerate(mcq_options[i]):
        print(f"{chr(65 + j)}) {option}")

    response = input("Your choice (A/B/C): ")
    response = response.lower()
    if (response == 'a'):
        visual_count += 1
    elif (response == 'b'):
        auditory_count += 1
    elif (response == 'c'):
        kinesthetic_count += 1

# Determine the dominant VAK preference
preferences = {
    "Visual": visual_count,
    "Auditory": auditory_count,
    "Kinesthetic": kinesthetic_count
}

dominant_preference = max(preferences, key=preferences.get)

# Print the results
print("\nVAK Learning Style Preferences:")
for style, count in preferences.items():
    print(f"{style}: {count} responses")

print("\nDominant Learning Style:", dominant_preference)
# Out:
# 1. 1. When operating new equipment for the first time I prefer to
# A) Read the instructions
# B) Listen to or ask for an explaination
# C) Have a go and learn by trial and error
# Your choice (A/B/C/D): a
# 2. 2. When seeking travel directions I
# A) Look at a map
# B) Ask for spoken directions
# C) Follow my nose or maybe use a compass
# Your choice (A/B/C/D): a
# 3. 3. When cooking a new dish I
# A) Follow a recipe
# B) Call a friend for explaination
# C) Follow my instinct, tasting as I cook
# Your choice (A/B/C/D): a
# 4. 4. To teach someone something I
# A) Write Instructions
# B) Explain verbally
# C) Demonstrate and let them have a go
# Your choice (A/B/C/D): a
# 5. 5. I tend to say
# A) I see what you mean
# B) I hear what you are saying
# C) I know how you feel
# Your choice (A/B/C/D): a
# 6. 6. I tend to say
# A) Show me
# B) Tell me
# C) Let me try
# Your choice (A/B/C/D): a
# 7. 7. I tend to say
# A) Watch how I do it
# B) Listen to me explain
# C) You have a go
# ...
